# %% [markdown]
# # AirBnB San Francisco Room Price Project
# #### Capstone 2 - Hallie McConlogue

# %% [markdown]
# # Problem Statement Worksheet (My Hypothesis)
# The business problem I am investigating is what rate I can charge on AirBnB for rooms in my family’s home in San Francisco in the next year.
#
# #### Focus
# For this solution I will focus on comparing features of the rooms I have to those being rented in San Francisco on AirBnB in order to get a good estimate for what I should charge per room.
#
#
# #### Data sources
# General market research:
# https://www.statista.com/statistics/206546/us-hotels-occupancy-rate-by-month/
#
# ##### AirBnB data
# Description:
# https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit#gid=982310896
# http://insideairbnb.com/get-the-data.html
#
# SF listings:
# http://data.insideairbnb.com/united-states/ca/san-francisco/2021-04-07/visualisations/listings.csv
#
#
# #### How I will solve the AirBnB problem in brief:
# Clean the data.
#
# Look at scatter plots of features and reviews vs room price.
#
# Build a heat map that shows what columns most affect room price.
#
# Normalize significant column values with each other.
#
# Run machine analysis to find appropriate market value for my rooms.
#
#
# ## Data wrangling goals:
#
# #### Data Collection Time estimate: 1-2 hours
# ■ Data loading -done
#
# ■ Data joining - first pass done
#
# ■ Import pandas library, for read_csv() -done
#
# ■ try merge, join, or concatenate. -first pass done
#
# #### Data Organization - Time estimate: 1-2 hours
# ■ File structure - done
#
# ■ GitHub - done
#
# ■ Hint: the glob library could come in handy here…  Should I use this here Ben?
#
# ■ Why GitHub again? Done: portfolio comits to bring you back to pre mistake co work with mentor?  other students?
#
# #### Data Definition - understanding of your data - Time estimate: 1-2 hours
# ■ Description of the columns good look close at them - done
#
# ■ Counts and percents unique values -  done
#
# ■ Names accurate - done
#
# ■ Data types of your columns right - done? ... mostly
#
# ■ Statistics for columns,
#     - mean,
#     - median,
#     - mode,
#     - standard deviation,
#     - range, and
#     - number of unique values.
#
# ■ Conclusions?
#
# ■ investigate further?
#
# ### Data Cleaning - Time estimate: 1-2 hours
# ■ NA or missing values - done
#
# ■ Duplicates ...
#
# #### Use these:
# ■ loc[] - filter your data by label
#
# ■ iloc[] - filter your data by indexes -- doesn't apply
#
# ■ apply() - execute a function across an axis of a DataFrame
#
# ■ drop() - drop columns from a DataFrame - done
#
# ■ is_unique() - check if a column is a unique identifier
#
# ■ Series methods:
#     - str.contains(), which can be used to check if a certain substring occurs in a string of a Series, and
#     - str.extract(), which can be used to extract capture groups with a certain regex (or regular expression) pattern
#
# ■ numPy methods like
#     - .where(), to clean columns. Recall that such methods have the structure: np.where(condition, then, else)
#
#
# ■ DataFrame methods to check for null values, such as  - done
#     - df.isnull().values.any()

# %% [markdown]
# ### Importing packages needed to complete project:

# %%
#Code task 1#
#Import pandas, matplotlib.pyplot, and seaborn in the correct lines below
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import matplotlib.pyplot as plot
import datetime

# %% [markdown]
# ### Loading files

# %%
# the supplied CSV data file is the raw_data directory
listings_data = pd.read_csv('../raw_data/listings.csv')
description = pd.read_csv('../raw_data/AirBnB_Col_Desc.csv')

# %% [markdown]
# ### Column Descriptions

# %%
description.style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
# #T_3638d3f2_c8a9_11eb_bae6_cc483a556361row0_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row0_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row1_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row1_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row2_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row2_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row3_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row3_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row4_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row4_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row5_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row5_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row6_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row6_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row7_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row7_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row8_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row8_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row9_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row9_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row10_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row10_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row11_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row11_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row12_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row12_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row13_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row13_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row14_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row14_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row15_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row15_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row16_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row16_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row17_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row17_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row18_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row18_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row19_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row19_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row20_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row20_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row21_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row21_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row22_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row22_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row23_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row23_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row24_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row24_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row25_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row25_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row26_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row26_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row27_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row27_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row28_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row28_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row29_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row29_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row30_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row30_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row31_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row31_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row32_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row32_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row33_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row33_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row34_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row34_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row35_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row35_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row36_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row36_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row37_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row37_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row38_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row38_col1,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row39_col0,#T_3638d3f2_c8a9_11eb_bae6_cc483a556361row39_col1,#T_3638d3f2_c8a9_11e ...
#             text-align:  left;
#         }</style><table id="T_3638d3f2_c8a9_11eb_bae6_cc483a556361" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Column</th>        <th class="col_heading level0 col1" >Description </th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3638d3f2_c8a9_11eb_bae6_cc483a556361level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3638d3f2_c8a9_11eb_bae6_cc483a556361row0_col0" class="data row0 col0" >host_id</td>
#                         <td id="T_3638d3f2_c8a9_11eb_bae6_cc483a556361row0_col1" class="data row0 col1" >Airbnb's unique identifier for the host/user</td>
#             </tr>
#             <tr>
#                         <th id="T_3638d3f2_c8a9_11eb_bae6_cc483a556361level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3638d3f2_c8a9_11eb_bae6_cc483a556361row1_col0" class="data row1 col0" >host_url</td>
#                         <td id="T_3638d3f2_c8a9_11eb_bae6_cc483a556361row1_col1" class="data row1 col1" >The Airbnb page for the host</td>
#             </tr>
#             <tr>
#                         <th id="T_3638d3f2_c8a9_11eb_bae6_cc483a556361level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3638d3f2_c8a9_11eb_bae6_cc483a556361row2_col0" class="data row2 col0" >

# %% [markdown]
# ### Identifying key column and features of interest
# Price is the value we find correlations on.

# %% [markdown]
# ### Data Types

# %%
listings_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6682 entries, 0 to 6681
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            6682 non-null   int64
#  1   listing_url                                   6682 non-null   object
#  2   scrape_id                                     6682 non-null   int64
#  3   last_scraped                                  6682 non-null   object
#  4   name                                          6682 non-null   object
#  5   description                                   6609 non-null   object
#  6   neighborhood_overview                         4777 non-null   object
#  7   picture_url                                   6682 non-null   object
#  8   host_id                                       6682 non-null   int64
#  9   host_url                                      6682 non-null   object
#  10  host_name                                     6341 non-null   object
#  11  host_since                                    6341 non-null   object
#  12  host_location                                 6336 non-null   object
#  13  host_about                                    4521 non-null   object
#  14  host_response_time                            4877 non-null   object
#  15  host_response_rate                            4877 non-null   object
#  16  host_acceptance_rate                          5007 non-null   object
#  17  host_is_superhost                             6341 non-null   object
#  18  host_thumbnail_url                            6341 non-null   object
#  19  host_picture_url                              6341 non-null   object
#  20  host_neighbourhood                            5918 non-null   object
#  21  host_listings_count                           6341 non-null   float64
#  22  host_total_listings_count                     6341 non-null   float64
#  23  host_verifications                            6682 non-null   object
#  24  host_has_profile_pic                          6341 non-null   object
#  25  host_identity_verified                        6341 non-null   object
#  26  neighbourhood                                 4777 non-null   object
#  27  neighbourhood_cleansed                        6682 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      6682 non-null   float64
#  30  longitude                                     6682 non-null   float64
#  31  property_type                                 6682 non-null   object
#  32  room_type                                     6682 non-null   object
#  33  accommodates                                  6682 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                6676 non-null   object
#  36  bedrooms                                      5800 non-null   float64
#  37  beds                                          6634 non-null   float64
#  38  amenities                                     6682 non-null   object
#  39  price                                         6682 non-null   object
#  40  minimum_nights                                6682 non-null   int64
#  41  maximum_nights                                6682 non-null   int64
#  42  minimum_minimum_nights                        6681 non-null   float64
#  43  maximum_minimum_nights                        6681 non-null   float64
#  44  minimum_maximum_nights                        6681 non-null   float64
#  45  maximum_maximum_nights                        6681 non-null   float64
#  46  minimum_nights_avg_ntm                        6681 non-null   float64
#  47  maximum_nights_avg_ntm                        6681 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              6682 non-null   object
#  50  availability_30                               6682 non-null   int64
#  51  availability_60                               6682 non-null   int64
#  52  availability_90                               6682 non-null   int64
#  53  availability_365                              6682 non-null   int64
#  54  calendar_last_scraped                         6682 non-null   object
#  55  number_of_reviews                             6682 non-null   int64
#  56  number_of_reviews_ltm                         6682 non-null   int64
#  57  number_of_reviews_l30d                        6682 non-null   int64
#  58  first_review                                  5010 non-null   object
#  59  last_review                                   5010 non-null   object
#  60  review_scores_rating                          4972 non-null   float64
#  61  review_scores_accuracy                        4947 non-null   float64
#  62  review_scores_cleanliness                     4947 non-null   float64
#  63  review_scores_checkin                         4946 non-null   float64
#  64  review_scores_communication                   4948 non-null   float64
#  65  review_scores_location                        4946 non-null   float64
#  66  review_scores_value                           4946 non-null   float64
#  67  license                                       3728 non-null   object
#  68  instant_bookable                              6682 non-null   object
#  69  calculated_host_listings_count                6682 non-null   int64
#  70  calculated_host_listings_count_entire_homes   6682 non-null   int64
#  71  calculated_host_listings_count_private_rooms  6682 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   6682 non-null   int64
#  73  reviews_per_month                             5010 non-null   float64
# dtypes: float64(23), int64(17), object(34)
# memory usage: 3.8+ MB

# %% [markdown]
# ### checking out the data quality

# %%
listings_data.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   958   https://www.airbnb.com/rooms/958  20210407173733   2021-04-10
# 1  5858  https://www.airbnb.com/rooms/5858  20210407173733   2021-04-08
# 2  7918  https://www.airbnb.com/rooms/7918  20210407173733   2021-04-08
# 3  8142  https://www.airbnb.com/rooms/8142  20210407173733   2021-04-08
# 4  8339  https://www.airbnb.com/rooms/8339  20210407173733   2021-04-07
#
#                                                 name  \
# 0              Bright, Modern Garden Unit - 1BR/1BTH
# 1                                 Creative Sanctuary
# 2         A Friendly Room - UCSF/USF - San Francisco
# 3  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                    Historic Alamo Square Victorian
#
#                                          description  \
# 0  Please check local laws re Covid before you re...
# 1  <b>The space</b><br />We live in a large Victo...
# 2  Nice and good public transportation.  7 minute...
# 3  Nice and good public transportation.  7 minute...
# 4  Pls email before booking. <br />Interior featu...
#
#                                neighborhood_overview  \
# 0  Quiet cul de sac in friendly neighborhood<br /...
# 1  I love how our neighborhood feels quiet but is...
# 2  Shopping old town, restaurants, McDonald, Whol...
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/b7c2a199-4c17...     1169
# 1  https://a0.muscache.com/pictures/17714/3a7aea1...     8904
# 2  https://a0.muscache.com/pictures/26356/8030652...    21994
# 3  https://a0.muscache.com/pictures/27832/3b1f9e5...    21994
# 4  https://a0.muscache.com/pictures/213fbf05-3545...    24215
#
#                                   host_url  ... review_scores_communication  \
# 0   https://www.airbnb.com/users/show/1169  ...                        10.0
# 1   https://www.airbnb.com/users/show/8904  ...                        10.0
# 2  https://www.airbnb.com/users/show/21994  ...                         9.0
# 3  https://www.airbnb.com/users/show/21994  ...                        10.0
# 4  https://www.airbnb.com/users/show/24215  ...                        10.0
#
#   review_scores_location review_scores_value      license instant_bookable  \
# 0                   10.0                10.0  STR-0001256                f
# 1                   10.0                 9.0          NaN                f
# 2                    9.0                 8.0          NaN                f
# 3                    9.0                 9.0          NaN                f
# 4                   10.0                10.0  STR-0000264                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              1                                           1
# 2                              8                                           0
# 3                              8                                           0
# 4                              2                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            8
# 3                                            8
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.94
# 1                                           0              0.76
# 2                                           0              0.13
# 3                                           0              0.10
# 4                                           0              0.20
#
# [5 rows x 74 columns]

# %% [markdown]
# ### cleaning the data

# %% [markdown]
# ### looking for missing data

# %%
missing = pd.concat([listings_data.isnull().sum(), 100 * listings_data.isnull().mean()], axis=1)
missing.columns=['count', '% missing']

missing_sorted = missing.sort_values(by='count', ascending=False)
print('missing_sorted:',type(missing_sorted))

missing_sorted.style.set_properties(**{'text-align': 'left'})
# Out:
# missing_sorted: <class 'pandas.core.frame.DataFrame'>
# <style  type="text/css" >
# #T_3648dcc6_c8a9_11eb_8886_cc483a556361row0_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row0_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row1_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row1_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row2_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row2_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row3_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row3_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row4_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row4_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row5_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row5_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row6_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row6_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row7_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row7_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row8_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row8_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row9_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row9_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row10_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row10_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row11_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row11_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row12_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row12_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row13_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row13_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row14_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row14_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row15_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row15_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row16_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row16_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row17_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row17_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row18_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row18_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row19_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row19_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row20_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row20_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row21_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row21_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row22_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row22_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row23_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row23_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row24_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row24_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row25_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row25_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row26_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row26_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row27_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row27_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row28_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row28_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row29_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row29_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row30_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row30_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row31_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row31_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row32_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row32_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row33_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row33_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row34_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row34_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row35_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row35_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row36_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row36_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row37_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row37_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row38_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row38_col1,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row39_col0,#T_3648dcc6_c8a9_11eb_8886_cc483a556361row39_col1,#T_3648dcc6_c8a9_11e ...
#             text-align:  left;
#         }</style><table id="T_3648dcc6_c8a9_11eb_8886_cc483a556361" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >% missing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3648dcc6_c8a9_11eb_8886_cc483a556361level0_row0" class="row_heading level0 row0" >neighbourhood_group_cleansed</th>
#                         <td id="T_3648dcc6_c8a9_11eb_8886_cc483a556361row0_col0" class="data row0 col0" >6682</td>

# %% [markdown]
# ## filling in missing data and converting types to numeric values by column

# %% [markdown]
# ### neighbourhood, neighbourhood_group_cleansed, calendar_updated, bathrooms
# No real info here, I will drop these columns.

# %%
listings_data['neighbourhood'].value_counts()
# Out:
# San Francisco, California, United States                  4770
# Daly City, California, United States                         2
# San Francisco , Ca, United States                            1
# San Francisco, Hayes Valley, California, United States       1
# Noe Valley - San Francisco, California, United States        1
# San Jose, California, United States                          1
# San Franscisco, California, United States                    1
# Name: neighbourhood, dtype: int64

# %%
listings_data = listings_data.drop(['neighbourhood_group_cleansed','calendar_updated','bathrooms'], axis=1)
listings_data = listings_data.drop(['neighbourhood'], axis=1)

# %% [markdown]
# ### license
# converting to a boolean value if you have a licence does it increase value?

# %%
#listings_data['license'].value_counts().head(60)

# %%
listings_data['license'] = listings_data['license'].isnull() == False
listings_data['license'].value_counts()
# Out:
# True     3728
# False    2954
# Name: license, dtype: int64

# %% [markdown]
# ### host_about
# Putting it empty space when this is not filled in

# %%
listings_data['host_about']= listings_data['host_about'].fillna("")
listings_data['neighborhood_overview']= listings_data['neighborhood_overview'].fillna("")

# %% [markdown]
# ## Host Response
# ### host_response_rate Does this indicate weather or not the room was rented?
# I compared this to reviews and analysed the airbnb system and how it works.  I looked up the definition more closely.
#
# ##### conclusion:
# The host response N/A relates more to when the listing is available for later but not now (possibly covid)  Or Just listed recently... if it were listed but not responded to at all there would be a bad mark on the listing instead of N/A ... I think.  Also there has been a move to 30 day rentals which would reduce the need for responses withing a 30 day limit of the response rate.
#
# There is good value numeric data here but a lot is missing.  After looking closely filling in an average would be best here. It seems these are the listings that were not sold in that month.  Listings may or may not have been ignored or unused, or somehow the data for these fields just didn't make it in for this time period.

# %%
listings_data['host_response_rate'].isna().sum()
# Out:
# 1805

# %%
listings_data['host_response_rate']=listings_data['host_response_rate'].str.replace('%','')

# %%
listings_data['host_response_rate'] = pd.to_numeric(listings_data['host_response_rate'])
#listings_data['host_response_rate'].value_counts()

# %% [markdown]
# ##### Splitting off the more active listings into Host_responded

# %%
Host_responded = listings_data.dropna(axis=0, subset=['host_response_rate'])

# %%
#Host_responded['host_response_rate'].isna().sum()
Host_responded['host_response_time'].isna().sum()
# Out:
# 0

# %% [markdown]
# ##### Averaging response and ratings to fill missing data into filled_avg

# %%
responseMeanAll = listings_data['host_response_rate'].mean()

# %%
filled_avg = listings_data

# %%
filled_avg['host_response_rate'] = listings_data['host_response_rate'].fillna(responseMeanAll)

# %% [markdown]
# #### Filling in average of host response time:

# %%
filled_avg['host_response_time'].value_counts()
# Out:
# within an hour        2991
# within a few hours    1054
# within a day           677
# a few days or more     155
# Name: host_response_time, dtype: int64

# %%
filled_avg['host_response_time'] = filled_avg['host_response_time'].str.replace('within an hour','1')
filled_avg['host_response_time'] = filled_avg['host_response_time'].str.replace('within a few hours','2')
filled_avg['host_response_time'] = filled_avg['host_response_time'].str.replace('within a day','3')
filled_avg['host_response_time'] = filled_avg['host_response_time'].str.replace('a few days or more','4')

# %%
filled_avg['host_response_time'] = pd.to_numeric(filled_avg['host_response_time'])

# %%
RTimeAv = filled_avg['host_response_time'].mean()

# %%
filled_avg['host_response_time'] = filled_avg['host_response_time'].fillna(RTimeAv)

# %% [markdown]
# #### host_acceptance_rate

# %%
filled_avg['host_acceptance_rate'].value_counts()
# Out:
# 100%    1712
# 99%      311
# 98%      297
# 0%       208
# 50%      202
#         ...
# 10%        1
# 13%        1
# 49%        1
# 47%        1
# 3%         1
# Name: host_acceptance_rate, Length: 88, dtype: int64

# %%
filled_avg['host_acceptance_rate']=filled_avg['host_acceptance_rate'].str.replace('%','')
filled_avg['host_acceptance_rate'] = pd.to_numeric(filled_avg['host_acceptance_rate'])
AcceptAv = filled_avg['host_acceptance_rate'].mean()
filled_avg['host_acceptance_rate'] = filled_avg['host_acceptance_rate'].fillna(AcceptAv)

# %% [markdown]
# ### Filling in reviews with average
# I'm assuming that some people are just too time stressed to give a review.  Also a lot of these will have no review because it has not yet been rented or the rental time is far in the future.
# #### review_scores

# %%
#filled_avg['review_scores_rating'] = pd.to_numeric(filled_avg['review_scores_rating'])

reviewAvg = filled_avg['review_scores_rating'].mean()
filled_avg['review_scores_rating'] = filled_avg['review_scores_rating'].fillna(reviewAvg)

reviewAvg = filled_avg['review_scores_value'].mean()
filled_avg['review_scores_value'] = filled_avg['review_scores_value'].fillna(reviewAvg)

reviewAvg = filled_avg['review_scores_checkin'].mean()
filled_avg['review_scores_checkin'] = filled_avg['review_scores_checkin'].fillna(reviewAvg)

reviewAvg = filled_avg['review_scores_location'].mean()
filled_avg['review_scores_location'] = filled_avg['review_scores_location'].fillna(reviewAvg)

reviewAvg = filled_avg['review_scores_cleanliness'].mean()
filled_avg['review_scores_cleanliness'] = filled_avg['review_scores_cleanliness'].fillna(reviewAvg)

reviewAvg = filled_avg['review_scores_accuracy'].mean()
filled_avg['review_scores_accuracy'] = filled_avg['review_scores_accuracy'].fillna(reviewAvg)

reviewAvg = filled_avg['review_scores_communication'].mean()
filled_avg['review_scores_communication'] = filled_avg['review_scores_communication'].fillna(reviewAvg)

# %% [markdown]
# #### Reveiws per month

# %%
reviewAvg = filled_avg['reviews_per_month'].mean()
filled_avg['reviews_per_month'] = filled_avg['reviews_per_month'].fillna(reviewAvg)

# %% [markdown]
# #### Reveiw Dates

# %%
#first_review
tomorrow = datetime.date.today() + datetime.timedelta(days=1)

filled_avg['first_review'] = pd.to_datetime(filled_avg['first_review'])
filled_avg['first_review'] = filled_avg['first_review'].fillna(tomorrow)

#last_review
#filled_avg['last_review'] = filled_avg['last_review'].astype('datetime64[ns]')
filled_avg['last_review'] = pd.to_datetime(filled_avg['last_review'])
filled_avg['last_review'] = filled_avg['last_review'].fillna(tomorrow)
#filled_avg['last_review'].value_counts()
#type(filled_avg['last_review'][0])

# %% [markdown]
# ### Bedrooms

# %%
#type(filled_avg['bedrooms'][0])
BedroomAvg = filled_avg['bedrooms'].mean()
filled_avg['bedrooms'] = filled_avg['bedrooms'].fillna(BedroomAvg)
filled_avg['bedrooms'].value_counts()
# Out:
# 1.000000    3878
# 2.000000    1217
# 1.497414     882
# 3.000000     521
# 4.000000     139
# 5.000000      28
# 6.000000      10
# 8.000000       3
# 7.000000       3
# 9.000000       1
# Name: bedrooms, dtype: int64

# %% [markdown]
# ### host_neighbourhood

# %%
filled_avg['host_neighbourhood']= filled_avg['host_neighbourhood'].fillna("")
filled_avg['host_location']= filled_avg['host_location'].fillna("")
#filled_avg['host_location'].value_counts()

# %% [markdown]
# ### host_listings_count
# fill with one

# %%
filled_avg['host_listings_count']= filled_avg['host_listings_count'].fillna(1)
#host_total_listings_count
filled_avg['host_total_listings_count']= filled_avg['host_total_listings_count'].fillna(1)

# %% [markdown]
# ### host_identity_verified

# %%
filled_avg['host_identity_verified']= filled_avg['host_identity_verified'].fillna(False)
filled_avg['host_name']= filled_avg['host_name'].fillna("")
filled_avg['host_is_superhost']= filled_avg['host_is_superhost'].fillna(False)
filled_avg['host_since']= filled_avg['host_since'].fillna("")

# %% [markdown]
# ### host_has_profile_pic

# %%
filled_avg['host_has_profile_pic']= filled_avg['host_has_profile_pic'].fillna(False)
filled_avg['host_picture_url']= filled_avg['host_picture_url'].fillna("")
filled_avg['host_thumbnail_url']= filled_avg['host_thumbnail_url'].fillna("")
filled_avg['description']= filled_avg['description'].fillna("")

# %% [markdown]
# #### saved ideas

# %%
#listings_data['last_review'].sort_values(ascending=True).head(60)
#listings_data['last_review', 'host_response_rate'].sort_values(by="last_review",ascending=True)

#missingRev = listings_data[['last_review','host_response_rate','review_scores_value','host_acceptance_rate','host_since']]
#missingRev = missingRev.sort_values(by='host_since', ascending=False)
#print('missingRev:',type(missingRev))
#missingRev.style.set_properties(**{'text-align': 'left'})


#tdf = listings_data.loc[listings_data['bedrooms'].isna()]
#noBedroom = listings_data.loc[listings_data['bedrooms'].isna()]
#noBedroom[['bedrooms', 'room_type']].value_counts('room_type')

#nbrea = noBedroom[noBedroom['room_type'] == 'Entire home/apt']

#nbrea[['room_type','property_type', 'bedrooms', 'beds', 'accommodates','review_scores_value']].sort_values('beds').head(60)

# %% [markdown]
# ### Beds

# %%
#peeking into data
#beds = filled_avg[filled_avg['beds'].isnull()]
#beds[['name','price','review_scores_rating', 'room_type']]
AvBed = filled_avg['beds'].mean()
filled_avg['beds']= filled_avg['beds'].fillna(AvBed)
filled_avg['bathrooms_text']= filled_avg['bathrooms_text'].fillna("")
filled_avg = filled_avg.dropna(axis=0, subset=['minimum_nights_avg_ntm'])

# %% [markdown]
# ## No more missing data all filled in:

# %%
missing2 = pd.concat([filled_avg.isnull().sum(), 100 * filled_avg.isnull().mean()], axis=1)
missing2.columns=['count', '% missing']

missing_sorted2 = missing2.sort_values(by='count', ascending=False)
print('missing_sorted2:',type(missing_sorted))

missing_sorted2.style.set_properties(**{'text-align': 'left'})
# Out:
# missing_sorted2: <class 'pandas.core.frame.DataFrame'>
# <style  type="text/css" >
# #T_369d7941_c8a9_11eb_b350_cc483a556361row0_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row0_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row1_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row1_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row2_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row2_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row3_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row3_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row4_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row4_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row5_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row5_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row6_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row6_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row7_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row7_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row8_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row8_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row9_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row9_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row10_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row10_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row11_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row11_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row12_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row12_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row13_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row13_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row14_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row14_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row15_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row15_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row16_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row16_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row17_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row17_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row18_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row18_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row19_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row19_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row20_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row20_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row21_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row21_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row22_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row22_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row23_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row23_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row24_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row24_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row25_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row25_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row26_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row26_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row27_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row27_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row28_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row28_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row29_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row29_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row30_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row30_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row31_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row31_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row32_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row32_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row33_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row33_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row34_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row34_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row35_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row35_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row36_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row36_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row37_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row37_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row38_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row38_col1,#T_369d7941_c8a9_11eb_b350_cc483a556361row39_col0,#T_369d7941_c8a9_11eb_b350_cc483a556361row39_col1,#T_369d7941_c8a9_11e ...
#             text-align:  left;
#         }</style><table id="T_369d7941_c8a9_11eb_b350_cc483a556361" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >% missing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_369d7941_c8a9_11eb_b350_cc483a556361level0_row0" class="row_heading level0 row0" >id</th>
#                         <td id="T_369d7941_c8a9_11eb_b350_cc483a556361row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_369d7941_c8a9_11eb_b350_cc483a556361row0_col1" class="data row0 col1" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_369d7941_c8a9_11eb_b350_cc483a556361level0_row1" class="row_heading level0 row1" >maximum_nights_avg_ntm</th>
#                         <td id="T_369d7941_c8a9_11eb_b350_cc483a556361row1_col0" class="data row1 col0" >0</td>
#                         <td id="T

# %% [markdown]
# # looking at my nieghborhood

# %%
filled_avg[filled_avg['host_neighbourhood']=='Bernal Heights'].head(60)
# Out:
#           id                           listing_url       scrape_id  \
# 22     29373    https://www.airbnb.com/rooms/29373  20210407173733
# 24     32414    https://www.airbnb.com/rooms/32414  20210407173733
# 27     39418    https://www.airbnb.com/rooms/39418  20210407173733
# 38     53280    https://www.airbnb.com/rooms/53280  20210407173733
# 45     57561    https://www.airbnb.com/rooms/57561  20210407173733
# 64     71645    https://www.airbnb.com/rooms/71645  20210407173733
# 94    132441   https://www.airbnb.com/rooms/132441  20210407173733
# 118   199480   https://www.airbnb.com/rooms/199480  20210407173733
# 132   229319   https://www.airbnb.com/rooms/229319  20210407173733
# 140   258786   https://www.airbnb.com/rooms/258786  20210407173733
# 173   348580   https://www.airbnb.com/rooms/348580  20210407173733
# 182   394575   https://www.airbnb.com/rooms/394575  20210407173733
# 186   409549   https://www.airbnb.com/rooms/409549  20210407173733
# 201   467507   https://www.airbnb.com/rooms/467507  20210407173733
# 206   479415   https://www.airbnb.com/rooms/479415  20210407173733
# 714    https://www.airbnb.com/users/show/672097  ...
# 718   https://www.airbnb.com/users/show/5739451  ...
# 768   https://www.airbnb.com/users/show/3400909  ...
# 783   https://www.airbnb.com/users/show/3608449  ...
# 813   https://www.airbnb.com/users/show/4346065  ...
# 823  https://www.airbnb.com/users/show/12514131  ...
# 833  https://www.airbnb.com/users/show/17349647  ...
# 880   https://www.airbnb.com/users/show/1525506  ...
# 896  https://www.airbnb.com/users/show/21235826  ...
# 900  https://www.airbnb.com/users/show/21235826  ...
# 907   https://www.airbnb.com/users/show/8990678  ...
# 927  https://www.airbnb.com/users/show/22662933  ...
# 948  https://www.airbnb.com/users/show/23262043  ...
# 958  https://www.airbnb.com/users/show/16884266  ...
#
#     review_scores_communication review_scores_location review_scores_value  \
# 22                    10.000000               9.000000           10.000000
# 24                    10.000000               9.000000            9.000000
# 27                    10.000000              10.000000            9.000000
# 38                    10.000000              10.000000           10.000000
# 45                     9.000000               9.000000            9.000000
# 64                    10.000000               9.000000            9.000000
# 94                    10.000000              10.000000           10.000000
# 118                   10.000000              10.000000           10.000000
# 132                   10.000000               9.000000            9.000000
# 140                   10.000000               9.000000            9.000000
# 173                   10.000000               9.000000            9.000000
# 182                   10.000000              10.000000           10.000000
# 186                   10.000000              10.000000           10.000000
# 201                   10.000000              10.000000           10.000000
# 206                   10.000000              10.000000            9.000000
# 218                   10.000000               9.000000            9.000000
# 226                   10.000000               9.000000            9.000000
# 249                   10.000000               9.000000            9.000000
# 254                   10.000000              10.000000           10.000000
# 264                   10.000000              10.000000           10.000000
# 308                   10.000000              10.000000            9.000000
# 333                   10.000000              10.000000            9.000000
# 348                   10.000000              10.000000           10.000000
# 359                   10.000000              10.000000            9.000000
# 407                   10.000000              10.000000           10.000000
# 442                   10.000000              10.000000           10.000000
# 449                   10.000000              10.000000            9.000000
# 458                   10.000000              10.000000           10.000000
# 460                   10.000000              10.000000           10.000000
# 464                   10.000000              10.000000            9.000000
# 496                   10.000000              10.000000            8.000000
# 502                   10.000000               9.000000            9.000000
# 513                   10.000000              10.000000           10.000000
# 517                   10.000000              10.000000            9.000000
# 530                   10.000000              10.000000           10.000000
# 574                   10.000000               8.000000            6.000000
# 582                   10.000000              10.000000           10.000000
# 619                    9.000000               9.000000            9.000000
# 623                   10.000000              10.000000           10.000000
# 627                   10.000000              10.000000            9.000000
# 658                   10.000000              10.000000           10.000000
# 659                   10.000000              10.000000           10.000000
# 681                   10.000000              10.000000           10.000000
# 688                    9.774859               9.697938            9.364941
# 699                   10.000000              10.000000            9.000000
# 710                    9.000000               9.000000            9.000000
# 714                   10.000000              10.000000           10.000000
# 718                   10.000000              10.000000           10.000000
# 768                   10.000000              10.000000           10.000000
# 783                   10.000000              10.000000            9.000000
# 813                   10.000000              10.000000           10.000000
# 823                   10.000000               9.000000            9.000000
# 833                   10.000000              10.000000           10.000000
# 880                    9.000000               9.000000            8.000000
# 896                   10.000000              10.000000           10.000000
# 900                   10.000000              10.000000           10.000000
# 907                   10.000000              10.000000           10.000000
# 927                   10.000000              10.000000           10.000000
# 948                   10.000000              10.000000           10.000000
# 958                   10.000000              10.000000           10.000000
#
#     license  instant_bookable  calculated_host_listings_count  \
# 22     True                 f                               2
# 24     True                 f                               1
# 27    False                 f                               2
# 38     True                 f                               2
# 45     True                 f                               1
# 64     True                 f                               1
# 94     True                 f                               1
# 118    True                 t                               2
# 132   False                 f                               2
# 140    True                 f                               2
# 173    True                 f                               1
# 182    True                 f                               1
# 186    True                 f                               1
# 201    True                 t                               1
# 206    True                 f                               1
# 218    True                 t                               2
# 226    True                 t                               1
# 249   False                 f                               2
# 254   False                 f                               2
# 264    True                 t                               1
# 308    True                 f                               1
# 333    True                 f                               2
# 348    True                 f                               1
# 359    True                 t                               3
# 407    True                 f                               1
# 442    True                 f                               1
# 449    True                 f                               1
# 458   False                 f                               1
# 460    True                 f                               3
# 464   False                 f                               2
# 496   False                 f                               1
# 502    True                 f                               4
# 513    True                 f                               1
# 517    True                 f                               1
# 530    True                 f                               1
# 574   False                 f                               2
# 582    True                 t                               1
# 619   False                 f                               5
# 623    True                 f                               1
# 627   False                 f                               5
# 658    True                 f                               1
# 659    True                 t                               1
# 681    True                 f                               1
# 688   False                 f                               1
# 699    True                 f                               2
# 710    True                 f                               2
# 714    True                 f                               1
# 718    True                 f                               1
# 768   False                 f                               1
# 783    True                 t                               3
# 813    True                 f                               2
# 823    True                 f                               1
# 833    True                 f                               1
# 880   False                 f                               1
# 896    True                 t                               2
# 900    True                 t                               2
# 907    True                 f                               2
# 927    True                 f                               1
# 948    True                 f                               1
# 958    True                 f                               1
#
#      calculated_host_listings_count_entire_homes  \
# 22                                             1
# 24                                             1
# 27                                             2
# 38                                             1
# 45                                             1
# 64                                             1
# 94                                             0
# 118                                            0
# 132                                            2
# 140                                            1
# 173                                            1
# 182                                            1
# 186                                            1
# 201                                            1
# 206                                            1
# 218                                            1
# 226                                            1
# 249                                            0
# 254                                            0
# 264                                            0
# 308                                            1
# 333                                            2
# 348                                            1
# 359                                            2
# 407                                            1
# 442                                            0
# 449                                            1
# 458                                            1
# 460                                            3
# 464                                            2
# 496                                            1
# 502                                            1
# 513                                            1
# 517                                            1
# 530                                            0
# 574                                            0
# 582                                            1
# 619                                            5
# 623                                            0
# 627                                            5
# 658                                            1
# 659                                            0
# 681                                            1
# 688                                            0
# 699                                            2
# 710                                            2
# 714                                            1
# 718                                            1
# 768                                            1
# 783                                            2
# 813                                            2
# 823                                            1
# 833                                            1
# 880                                            0
# 896                                            0
# 900                                            0
# 907                                            2
# 927                                            1
# 948                                            1
# 958                                            1
#
#     calculated_host_listings_count_private_rooms  \
# 22                                             1
# 24                                             0
# 27                                             0
# 38                                             1
# 45                                             0
# 64                                             0
# 94                                             1
# 118                                            2
# 132                                            0
# 140                                            1
# 173                                            0
# 182                                            0
# 186                                            0
# 201                                            0
# 206                                            0
# 218                                            1
# 226                                            0
# 249                                            1
# 254                                            1
# 264                                            1
# 308                                            0
# 333                                            0
# 348                                            0
# 359                                            1
# 407                                            0
# 442                                            1
# 449                                            0
# 458                                            0
# 460                                            0
# 464                                            0
# 496                                            0
# 502                                            3
# 513                                            0
# 517                                            0
# 530                                            1
# 574                                            2
# 582                                            0
# 619                                            0
# 623                                            1
# 627                                            0
# 658                                            0
# 659                                            1
# 681                                            0
# 688                                            1
# 699                                            0
# 710                                            0
# 714                                            0
# 718                                            0
# 768                                            0
# 783                                            1
# 813                                            0
# 823                                            0
# 833                                            0
# 880                                            1
# 896                                            2
# 900                                            2
# 907                                            0
# 927                                            0
# 948                                            0
# 958                                            0
#
#     calculated_host_listings_count_shared_rooms reviews_per_month
# 22                                            0          0.140000
# 24                                            0          0.720000
# 27                                            0          0.190000
# 38                                            0          1.140000
# 45                                            0          1.720000
# 64                                            0          2.590000
# 94                                            0          1.120000
# 118                                           0          1.730000
# 132                                           0          0.160000
# 140                                           0          0.140000
# 173                                           0          0.320000
# 182                                           0          3.870000
# 186                                           0          0.860000
# 201                                           0          2.170000
# 206                                           0          0.220000
# 218                                           0          0.090000
# 226                                           0          0.230000
# 249                                           1          0.510000
# 254                                           1          0.020000
# 264                                           0          2.600000
# 308                                           0          0.880000
# 333                                           0          0.890000
# 348                                           0          0.880000
# 359                                           0          0.290000
# 407                                           0          1.830000
# 442                                           0          2.040000
# 449                                           0          0.340000
# 458                                           0          4.050000
# 460                                           0          0.140000
# 464                                           0          0.040000
# 496                                           0          0.110000
# 502                                           0          0.660000
# 513                                           0          1.440000
# 517                                           0          3.850000
# 530                                           0          1.550000
# 574                                           0          0.050000
# 582                                           0          4.650000
# 619                                           0          0.320000
# 623                                           0          2.210000
# 627                                           0          0.070000
# 658                                           0          1.810000
# 659                                           0          4.860000
# 681                                           0          0.240000
# 688                                           0          1.174543
# 699                                           0          0.850000
# 710                                           0          0.050000
# 714                                           0          5.060000
# 718                                           0          0.220000
# 768                                           0          0.200000
# 783                                           0          0.490000
# 813                                           0          0.350000
# 823                                           0          0.570000
# 833                                           0          4.780000
# 880                                           0          0.110000
# 896                                           0          3.900000
# 900                                           0          2.890000
# 907                                           0          0.290000
# 927                                           0          5.390000
# 948                                           0          0.210000
# 958                                           0          1.940000
#
# [60 rows x 70 columns]

# %% [markdown]
# ### Looking at price vs location rating

# %%
filled_avg.plot.scatter(x='price', y='review_scores_location', title= "location rating vs price");

plot.show(block=True);

# %% [markdown]
# ### neighborhood counts found a cleansed neighbourhood column

# %%
ldf = filled_avg['neighbourhood_cleansed'].value_counts()
hoodDF = ldf.to_frame()
hoodDF.style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
# #T_3aa285b0_c8a9_11eb_a154_cc483a556361row0_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row1_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row2_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row3_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row4_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row5_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row6_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row7_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row8_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row9_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row10_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row11_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row12_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row13_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row14_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row15_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row16_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row17_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row18_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row19_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row20_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row21_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row22_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row23_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row24_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row25_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row26_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row27_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row28_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row29_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row30_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row31_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row32_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row33_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row34_col0,#T_3aa285b0_c8a9_11eb_a154_cc483a556361row35_col0{
#             text-align:  left;
#         }</style><table id="T_3aa285b0_c8a9_11eb_a154_cc483a556361" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >neighbourhood_cleansed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row0" class="row_heading level0 row0" >Downtown/Civic Center</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row0_col0" class="data row0 col0" >725</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row1" class="row_heading level0 row1" >Mission</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row1_col0" class="data row1 col0" >592</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row2" class="row_heading level0 row2" >South of Market</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row2_col0" class="data row2 col0" >518</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row3" class="row_heading level0 row3" >Western Addition</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row3_col0" class="data row3 col0" >462</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row4" class="row_heading level0 row4" >Haight Ashbury</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row4_col0" class="data row4 col0" >333</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row5" class="row_heading level0 row5" >Castro/Upper Market</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row5_col0" class="data row5 col0" >311</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row6" class="row_heading level0 row6" >Bernal Heights</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row6_col0" class="data row6 col0" >298</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row7" class="row_heading level0 row7" >Nob Hill</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row7_col0" class="data row7 col0" >285</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row8" class="row_heading level0 row8" >Noe Valley</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row8_col0" class="data row8 col0" >258</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row9" class="row_heading level0 row9" >Outer Sunset</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row9_col0" class="data row9 col0" >253</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row10" class="row_heading level0 row10" >North Beach</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row10_col0" class="data row10 col0" >194</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row11" class="row_heading level0 row11" >Russian Hill</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row11_col0" class="data row11 col0" >192</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row12" class="row_heading level0 row12" >Financial District</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row12_col0" class="data row12 col0" >189</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row13" class="row_heading level0 row13" >Potrero Hill</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row13_col0" class="data row13 col0" >177</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row14" class="row_heading level0 row14" >Inner Richmond</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row14_col0" class="data row14 col0" >177</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row15" class="row_heading level0 row15" >Bayview</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row15_col0" class="data row15 col0" >164</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row16" class="row_heading level0 row16" >Marina</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row16_col0" class="data row16 col0" >155</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row17" class="row_heading level0 row17" >Chinatown</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row17_col0" class="data row17 col0" >145</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row18" class="row_heading level0 row18" >Outer Richmond</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row18_col0" class="data row18 col0" >145</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row19" class="row_heading level0 row19" >Pacific Heights</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a556361row19_col0" class="data row19 col0" >145</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa285b0_c8a9_11eb_a154_cc483a556361level0_row20" class="row_heading level0 row20" >Excelsior</th>
#                         <td id="T_3aa285b0_c8a9_11eb_a154_cc483a

# %%
messyHood = filled_avg['host_neighbourhood'].value_counts()
hoodMessDF = messyHood.to_frame()
hoodMessDF.style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
# #T_3aa51cfd_c8a9_11eb_b629_cc483a556361row0_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row1_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row2_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row3_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row4_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row5_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row6_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row7_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row8_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row9_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row10_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row11_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row12_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row13_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row14_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row15_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row16_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row17_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row18_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row19_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row20_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row21_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row22_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row23_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row24_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row25_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row26_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row27_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row28_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row29_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row30_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row31_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row32_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row33_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row34_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row35_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row36_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row37_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row38_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row39_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row40_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row41_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row42_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row43_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row44_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row45_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row46_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row47_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row48_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row49_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row50_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row51_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row52_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row53_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row54_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row55_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row56_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row57_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row58_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row59_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row60_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row61_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row62_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row63_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row64_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row65_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row66_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row67_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row68_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row69_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row70_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row71_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row72_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row73_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row74_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row75_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row76_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row77_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row78_col0,#T_3aa51cfd_c8a9_11eb_b629_cc483a556361row79_col0,#T_3aa51cf ...

# %% [markdown]
# ### How many listings in each neighborhood

# %%
#Specify a horizontal barplot ('barh') as kind of plot (kind=)
NPlot = filled_avg.neighbourhood_cleansed.value_counts().plot(kind='barh', figsize=(12, 8))
#Give the plot a helpful title of 'Neighborhood'
NPlot.set_title('San Francisco Neighborhood')
#Label the xaxis 'Listings'
NPlot.set_xlabel('AirBnB Listings')
# Out:
# Text(0.5, 0, 'AirBnB Listings')

# %% [markdown]
# ### Neighborhoods sorted by average price

# %%
filled_avg['price'] = filled_avg['price'].str.replace('$','')
filled_avg['price'] = filled_avg['price'].str.replace(',','')
filled_avg['price'] = pd.to_numeric(filled_avg['price'])
#filled_avg['price_per_bed'] = filled_avg['price']/filled_avg['beds']
filled_avg['price_per_bedroom'] = filled_avg['price']/filled_avg['bedrooms']
filled_avg['price_per_person'] = filled_avg['price']/filled_avg['accommodates']
# Out:
# <ipython-input-43-1360c45cc21a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filled_avg['price'] = filled_avg['price'].str.replace('$','')
# <ipython-input-43-1360c45cc21a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filled_avg['price'] = filled_avg['price'].str.replace(',','')
# <ipython-input-43-1360c45cc21a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filled_avg['price'] = pd.to_numeric(filled_avg['price'])
# <ipython-input-43-1360c45cc21a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filled_avg['price_per_bedroom'] = filled_avg['price']/filled_avg['bedrooms']
# <ipython-input-43-1360c45cc21a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filled_avg['price_per_person'] = filled_avg['price']/filled_avg['accommodates']

# %%
hood_price_means = filled_avg.groupby('neighbourhood_cleansed')['price','price_per_bedroom','price_per_person'].mean()

#hood_price_means = filled_avg.groupby('neighbourhood_cleansed')['price','price_per_bedroom'].mean()
#hood_price_means.sort_values()

(hood_price_means.reindex(index=hood_price_means.mean(axis=1)
    .sort_values(ascending=False)
    .index)
    .plot(kind='barh', figsize=(10, 10), title='Average ticket price by hood'))
plt.xlabel('Price ($)');
# Out:
# <ipython-input-44-17d687858146>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   hood_price_means = filled_avg.groupby('neighbourhood_cleansed')['price','price_per_bedroom','price_per_person'].mean()

# %%
filled_avg.hist(column='price')
# Out:
# array([[<AxesSubplot:title={'center':'price'}>]], dtype=object)

# %% [markdown]
# ### Price by Type of property

# %%
property_type_price_means = filled_avg.groupby('property_type')['price'].mean()
property_type_price_means.sort_values()
# Out:
# property_type
# Shared room in villa                    26.250000
# Shared room in bungalow                 37.000000
# Shared room in boutique hotel           42.333333
# Shared room in house                    43.137931
# Shared room in townhouse                50.000000
# Barn                                    51.000000
# Private room in bungalow                52.000000
# Shared room in hostel                   54.297872
# Shared room in condominium              73.666667
# Shared room in bed and breakfast        79.785714
# Private room in cottage                 80.666667
# Entire place                            81.000000
# Private room in house                   95.849282
# Private room in townhouse               97.523810
# Private room in villa                   98.500000
# Private room in treehouse              100.000000
# Private room in apartment              103.809932
# Private room in bed and breakfast      105.809524
# Private room in guest suite            105.963636
# Private room in condominium            113.148571
# Room in serviced apartment             114.333333
# Private room in hostel                 116.120000
# Tiny house                             120.000000
# Cycladic house                         124.000000
# Room in hostel                         131.000000
# Shared room in loft                    137.500000
# Entire in-law                          142.000000
# Private room                           143.000000
# Private room in loft                   152.875000
# Entire cabin                           153.000000
# Private room in cabin                  155.000000
# Entire guest suite                     159.859813
# Entire guesthouse                      171.674419
# Private room in guesthouse             178.333333
# Entire bungalow                        182.555556
# Shared room in apartment               189.863014
# Entire serviced apartment              190.342282
# Entire apartment                       199.441028
# Entire floor                           210.000000
# Entire cottage                         227.600000
# Entire loft                            235.600000
# Room in bed and breakfast              248.000000
# Private room in serviced apartment     256.000000
# Entire condominium                     261.219396
# Room in aparthotel                     304.142857
# Room in hotel                          313.382514
# Entire townhouse                       343.490196
# Entire house                           369.874294
# Entire resort                          428.571429
# Room in boutique hotel                 548.734463
# Private room in resort                1112.571429
# Castle                                1200.000000
# Entire villa                          2779.600000
# Name: price, dtype: float64

# %% [markdown]
# ### Unique property types - looking for oddities
# Is there anything that does not fit in the simplified types?

# %%
filled_avg['property_type'].value_counts().head(60)
# Out:
# Entire apartment                      1984
# Private room in house                  836
# Entire house                           708
# Entire condominium                     629
# Private room in apartment              584
# Entire guest suite                     428
# Room in boutique hotel                 354
# Room in hotel                          183
# Private room in condominium            175
# Entire serviced apartment              149
# Entire loft                             75
# Shared room in apartment                73
# Private room in guest suite             55
# Entire townhouse                        51
# Shared room in hostel                   47
# Entire guesthouse                       43
# Room in aparthotel                      42
# Private room in townhouse               42
# Shared room in house                    29
# Private room in hostel                  25
# Private room in bed and breakfast       21
# Private room                            17
# Entire cottage                          15
# Shared room in bed and breakfast        14
# Private room in resort                  14
# Entire bungalow                          9
# Private room in serviced apartment       8
# Private room in loft                     8
# Entire resort                            7
# Private room in guesthouse               6
# Entire villa                             5
# Room in hostel                           4
# Shared room in villa                     4
# Shared room in condominium               3
# Shared room in boutique hotel            3
# Tiny house                               3
# Room in serviced apartment               3
# Room in bed and breakfast                3
# Private room in cottage                  3
# Entire cabin                             2
# Castle                                   2
# Private room in villa                    2
# Shared room in townhouse                 2
# Shared room in loft                      2
# Private room in treehouse                1
# Entire place                             1
# Barn                                     1
# Private room in bungalow                 1
# Cycladic house                           1
# Entire floor                             1
# Shared room in bungalow                  1
# Private room in cabin                    1
# Entire in-law                            1
# Name: property_type, dtype: int64

# %% [markdown]
# ### Price by simplified type of property

# %%
room_type_price_means = filled_avg.groupby('room_type')['price'].mean()
room_type_price_means.sort_values()
#room_type_price_means/listings_data.bedrooms
# Out:
# room_type
# Shared room        110.365169
# Private room       186.137367
# Entire home/apt    241.565983
# Hotel room         306.680851
# Name: price, dtype: float64

# %%
colList = list(filled_avg.columns)
#print(colList)

# %%
numCols = ['host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_listings_count', 'host_total_listings_count', 'accommodates', 'bedrooms', 'beds', 'price', 'minimum_nights', 'maximum_nights', 'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'reviews_per_month', 'price_per_bedroom', 'price_per_person']

# %%
colList = list(filled_avg.columns)
NumericDF = filled_avg[numCols]

NumericDF.hist(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5);

# %%
NumericDF['price'].value_counts()
# Out:
# 150.0     169
# 250.0     143
# 100.0     127
# 90.0      125
# 125.0     108
#          ...
# 9285.0      1
# 1275.0      1
# 460.0       1
# 1046.0      1
# 597.0       1
# Name: price, Length: 546, dtype: int64

# %%
NumericDF.hist(column='price')
# Out:
# array([[<AxesSubplot:title={'center':'price'}>]], dtype=object)

# %% [markdown]
# ## Saving Data

# %%
filled_avg.shape
# Out:
# (6681, 72)

# %%
# save the data to a new csv file
datapath = '../data'
save_file(filled_avg, 'AirBnB_listings_averaged_cleaned.csv', datapath)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-fd8f1db90a98> in <module>
#       1 # save the data to a new csv file
#       2 datapath = '\data'
# ----> 3 save_file(filled_avg, 'AirBnB_listings_averaged_cleaned.csv', datapath)
#
# NameError: name 'save_file' is not defined
